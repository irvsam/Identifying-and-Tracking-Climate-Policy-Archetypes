# %%
import wbgapi as wb
import pandas as pd

# 1. Define 19 G20 sovereign nations
countries = ['ARG', 'AUS', 'BRA', 'CAN', 'CHN', 'FRA', 'DEU', 'IND', 
             'IDN', 'ITA', 'JPN', 'MEX', 'RUS', 'SAU', 'ZAF', 'KOR', 
             'TUR', 'GBR', 'USA']

# 2. Define indicators we are interested in TODO: add more indicators related to climate policy, energy transition, etc.
indicators = {
    'EG.USE.PCAP.KG.OE': 'energy_use_per_capita',
    'NY.GDP.MKTP.KD': 'gdp_constant_usd',
    'EG.ELC.RNWX.ZS': 'renewable_electricity_pct',
    'EG.ELC.COAL.ZS': 'coal_electricity_pct',
    'NY.GDP.PCAP.KD': 'gdp_per_capita_constant'
}

# 3. Fetch the data
# wbgapi automatically returns a clean pandas DataFrame
df_wb = wb.data.DataFrame(indicators.keys(), countries, time=range(2015, 2026), labels=False)

# Rename the columns to our readable names
df_wb = df_wb.rename(columns=indicators)

# Set display format to show 2 decimal places and avoid scientific notation
pd.options.display.float_format = '{:,.2f}'.format

# Now print data (head is enough to check if it looks correct)
print(df_wb.head())
# Out:
#                                       YR2015             YR2016  \
# economy series
# ARG     EG.ELC.COAL.ZS                  2.01               1.61
#         EG.ELC.RNWX.ZS                 -3.80              -2.94
#         EG.USE.PCAP.KG.OE           1,919.76           1,889.87
#         NY.GDP.MKTP.KD    594,749,285,413.21 582,376,550,428.09
#         NY.GDP.PCAP.KD             13,679.63          13,265.89
#
#                                       YR2017             YR2018  \
# economy series
# ARG     EG.ELC.COAL.ZS                  1.55               1.56
#         EG.ELC.RNWX.ZS                 -3.09              -2.69
#         EG.USE.PCAP.KG.OE           1,874.83           1,806.78
#         NY.GDP.MKTP.KD    598,790,850,843.68 583,118,120,294.00
#         NY.GDP.PCAP.KD             13,520.11          13,058.33
#
#                                       YR2019             YR2020  \
# economy series
# ARG     EG.ELC.COAL.ZS                  0.92               1.30
#         EG.ELC.RNWX.ZS                  1.50               6.17
#         EG.USE.PCAP.KG.OE           1,777.42           1,623.92
#         NY.GDP.MKTP.KD    571,450,737,224.44 514,874,343,768.07
#         NY.GDP.PCAP.KD             12,706.40          11,393.05
#
#                                       YR2021             YR2022  \
# economy series
# ARG     EG.ELC.COAL.ZS                  1.82               1.82
#         EG.ELC.RNWX.ZS                  9.06                NaN
#         EG.USE.PCAP.KG.OE           1,741.51           1,808.76
#         NY.GDP.MKTP.KD    568,636,554,720.07 602,872,713,790.92
#         NY.GDP.PCAP.KD             12,549.28          13,276.82
#
#                                       YR2023             YR2024  YR2025
# economy series
# ARG     EG.ELC.COAL.ZS                  1.41                NaN     NaN
#         EG.ELC.RNWX.ZS                   NaN                NaN     NaN
#         EG.USE.PCAP.KG.OE           1,832.07                NaN     NaN
#         NY.GDP.MKTP.KD    591,684,674,129.45 583,738,758,865.70     NaN
#         NY.GDP.PCAP.KD             12,993.09          12,774.35     NaN
