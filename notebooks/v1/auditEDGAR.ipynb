# %%
import sys
import os
import pandas as pd
import importlib

# 1. Setup path to import src
project_root = os.path.abspath(os.path.join(os.getcwd(), '..'))
if project_root not in sys.path:
    sys.path.append(project_root)

# 2. Import your loader (using reload to ensure changes in src/data_loader.py are picked up)
import src.data_loader
importlib.reload(src.data_loader)
from src.data_loader import load_edgar_data, get_edgar_citation

#load the data
df_edgar = load_edgar_data(directory='../data/raw/')

print("Data successfully loaded!")
print(f"Shape: {df_edgar.shape}")
print("-" * 30)
print(df_edgar.head())

# 5. Citation Reminder (Always keep this in your audit notebook for transparency)
print("\n--- Data Citation ---")
print(get_edgar_citation())
# Out:
# Data successfully loaded!
# Shape: (225, 15)
# ------------------------------
#       IPCC_annex       C_group_IM24_sh Country_code_A3           Name  \
# 0    Non-Annex_I  Rest Central America             ABW          Aruba
# 1    Non-Annex_I               India +             AFG    Afghanistan
# 2    Non-Annex_I       Southern_Africa             AGO         Angola
# 3    Non-Annex_I  Rest Central America             AIA       Anguilla
# 4  Int. Aviation         Int. Aviation             AIR  Int. Aviation
#
#   Substance         Y_2015         Y_2016         Y_2017         Y_2018  \
# 0       CO2     462.525510     485.393661     467.105070     465.294672
# 1       CO2    8427.155535    7611.693197   10397.247877   11809.927562
# 2       CO2   33086.542918   31274.846719   27995.052673   25814.217481
# 3       CO2      28.099137      28.435081      29.159123      28.319796
# 4       CO2  536452.291484  560444.870921  589881.613190  615737.003367
#
#           Y_2019         Y_2020         Y_2021         Y_2022         Y_2023  \
# 0     509.546670     488.734897     507.350518     535.465064     537.123842
# 1   12104.637732   12143.567553   12486.391316   11297.963866   11648.639184
# 2   26996.259751   20538.038803   25564.111022   26683.913660   27336.005252
# 3      27.676923      22.876156      22.090328      21.933841      21.917944
# 4  624897.243901  295699.052155  326402.533006  471471.369609  570728.500052
#
#           Y_2024
# 0     555.960988
# 1   12068.415172
# 2   28100.363831
# 3      22.768634
# 4  614153.494622
#
# --- Data Citation ---
# Emissions Database for Global Atmospheric Research (EDGAR), release EDGAR_2025_GHG (1970 - 2024) of September 2025. European Commission, Joint Research Centre (JRC). DOI: 10.2760/9816914
